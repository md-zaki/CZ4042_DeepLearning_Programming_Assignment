# %% [markdown]
# CS4001/4042 Assignment 1, Part B, Q1
# ---
#
# Real world datasets often have a mix of numeric and categorical features – this dataset is one example. To build models on such data, categorical features have to be encoded or embedded.
#
# PyTorch Tabular is a library that makes it very convenient to build neural networks for tabular data. It is built on top of PyTorch Lightning, which abstracts away boilerplate model training code and makes it easy to integrate other tools, e.g. TensorBoard for experiment tracking.
#
# For questions B1 and B2, the following features should be used:
# - **Numeric / Continuous** features: dist_to_nearest_stn, dist_to_dhoby, degree_centrality, eigenvector_centrality, remaining_lease_years, floor_area_sqm
# - **Categorical** features: month, town, flat_model_type, storey_range

# %% [markdown]
# ---

# %%
# !pip install pytorch_tabular[extra]
# Out:
# Requirement already satisfied: pytorch_tabular[extra] in c:\users\mdzak\anaconda3\envs\nnpartb\lib\site-packages (1.0.2)
# Requirement already satisfied: torch>=1.9.0 in c:\users\mdzak\anaconda3\envs\nnpartb\lib\site-packages (from pytorch_tabular[extra]) (2.0.1)
# Requirement already satisfied: category-encoders<2.7.0,>=2.6.0 in c:\users\mdzak\anaconda3\envs\nnpartb\lib\site-packages (from pytorch_tabular[extra]) (2.6.2)
# Requirement already satisfied: numpy>=1.17.2 in c:\users\mdzak\anaconda3\envs\nnpartb\lib\site-packages (from pytorch_tabular[extra]) (1.26.0)
# Requirement already satisfied: pandas>=1.1.5 in c:\users\mdzak\anaconda3\envs\nnpartb\lib\site-packages (from pytorch_tabular[extra]) (2.1.1)
# Requirement already satisfied: scikit-learn>=1.0.0 in c:\users\mdzak\anaconda3\envs\nnpartb\lib\site-packages (from pytorch_tabular[extra]) (1.3.1)
# Requirement already satisfied: pytorch-lightning<2.0.0,>=1.8.0 in c:\users\mdzak\anaconda3\envs\nnpartb\lib\site-packages (from pytorch_tabular[extra]) (1.9.5)
# Requirement already satisfied: omegaconf>=2.1.0 in c:\users\mdzak\anaconda3\envs\nnpartb\lib\site-packages (from pytorch_tabular[extra]) (2.3.0)
# Requirement already satisfied: torchmetrics<0.12.0,>=0.10.0 in c:\users\mdzak\anaconda3\envs\nnpartb\lib\site-packages (from pytorch_tabular[extra]) (0.11.4)
# Requirement already satisfied: tensorboard!=2.5.0,>2.2.0 in c:\users\mdzak\anaconda3\envs\nnpartb\lib\site-packages (from pytorch_tabular[extra]) (2.14.1)
# Requirement already satisfied: protobuf<4.23.0,>=3.20.0 in c:\users\mdzak\anaconda3\envs\nnpartb\lib\site-packages (from pytorch_tabular[extra]) (4.22.5)
# Requirement already satisfied: pytorch-tabnet==4.0 in c:\users\mdzak\anaconda3\envs\nnpartb\lib\site-packages (from pytorch_tabular[extra]) (4.0)
# Requirement already satisfied: PyYAML<6.1.0,>=5.4 in c:\users\mdzak\anaconda3\envs\nnpartb\lib\site-packages (from pytorch_tabular[extra]) (6.0.1)
# Requirement already satisfied: matplotlib>3.1 in c:\users\mdzak\anaconda3\envs\nnpartb\lib\site-packages (from pytorch_tabular[extra]) (3.8.0)
# Requirement already satisfied: ipywidgets in c:\users\mdzak\anaconda3\envs\nnpartb\lib\site-packages (from pytorch_tabular[extra]) (8.1.1)
# Requirement already satisfied: einops<0.7.0,>=0.6.0 in c:\users\mdzak\anaconda3\envs\nnpartb\lib\site-packages (from pytorch_tabular[extra]) (0.6.1)
# Requirement already satisfied: rich>=11.0.0 in c:\users\mdzak\anaconda3\envs\nnpartb\lib\site-packages (from pytorch_tabular[extra]) (13.6.0)
# Requirement already satisfied: wandb==0.13.* in c:\users\mdzak\anaconda3\envs\nnpartb\lib\site-packages (from pytorch_tabular[extra]) (0.13.11)
# Requirement already satisfied: plotly<5.15.0,>=5.13.0 in c:\users\mdzak\anaconda3\envs\nnpartb\lib\site-packages (from pytorch_tabular[extra]) (5.14.1)
# Requirement already satisfied: kaleido==0.2.* in c:\users\mdzak\anaconda3\envs\nnpartb\lib\site-packages (from pytorch_tabular[extra]) (0.2.1)
# Requirement already satisfied: scipy>1.4 in c:\users\mdzak\anaconda3\envs\nnpartb\lib\site-packages (from pytorch-tabnet==4.0->pytorch_tabular[extra]) (1.11.3)
# Collecting torch>=1.9.0 (from pytorch_tabular[extra])
#   Using cached torch-1.13.1-cp310-cp310-win_amd64.whl (162.6 MB)
# Requirement already satisfied: tqdm<5.0,>=4.36 in c:\users\mdzak\anaconda3\envs\nnpartb\lib\site-packages (from pytorch-tabnet==4.0->pytorch_tabular[extra]) (4.66.1)
# Requirement already satisfied: Click!=8.0.0,>=7.0 in c:\users\mdzak\anaconda3\envs\nnpartb\lib\site-packages (from wandb==0.13.*->pytorch_tabular[extra]) (8.1.7)
# Requirement already satisfied: GitPython!=3.1.29,>=1.0.0 in c:\users\mdzak\anaconda3\envs\nnpartb\lib\site-packages (from wandb==0.13.*->pytorch_tabular[extra]) (3.1.37)
# Requirement already satisfied: requests<3,>=2.0.0 in c:\users\mdzak\anaconda3\envs\nnpartb\lib\site-packages (from wandb==0.13.*->pytorch_tabular[extra]) (2.31.0)
# Requirement already satisfied: psutil>=5.0.0 in c:\users\mdzak\anaconda3\envs\nnpartb\lib\site-packages (from wandb==0.13.*->pytorch_tabular[extra]) (5.9.5)
# Requirement already satisfied: sentry-sdk>=1.0.0 in c:\users\mdzak\anaconda3\envs\nnpartb\lib\site-packages (from wandb==0.13.*->pytorch_tabular[extra]) (1.31.0)
# Requirement already satisfied: docker-pycreds>=0.4.0 in c:\users\mdzak\anaconda3\envs\nnpartb\lib\site-packages (from wandb==0.13.*->pytorch_tabular[extra]) (0.4.0)
# Requirement already satisfied: pathtools in c:\users\mdzak\anaconda3\envs\nnpartb\lib\site-packages (from wandb==0.13.*->pytorch_tabular[extra]) (0.1.2)
# Requirement already satisfied: setproctitle in c:\users\mdzak\anaconda3\envs\nnpartb\lib\site-packages (from wandb==0.13.*->pytorch_tabular[extra]) (1.3.2)
# Requirement already satisfied: setuptools in c:\users\mdzak\anaconda3\envs\nnpartb\lib\site-packages (from wandb==0.13.*->pytorch_tabular[extra]) (68.2.2)
# Requirement already satisfied: appdirs>=1.4.3 in c:\users\mdzak\anaconda3\envs\nnpartb\lib\site-packages (from wandb==0.13.*->pytorch_tabular[extra]) (1.4.4)
# Requirement already satisfied: statsmodels>=0.9.0 in c:\users\mdzak\anaconda3\envs\nnpartb\lib\site-packages (from category-encoders<2.7.0,>=2.6.0->pytorch_tabular[extra]) (0.14.0)
# Requirement already satisfied: patsy>=0.5.1 in c:\users\mdzak\anaconda3\envs\nnpartb\lib\site-packages (from category-encoders<2.7.0,>=2.6.0->pytorch_tabular[extra]) (0.5.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\mdzak\anaconda3\envs\nnpartb\lib\site-packages (from matplotlib>3.1->pytorch_tabular[extra]) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\mdzak\anaconda3\envs\nnpartb\lib\site-packages (from matplotlib>3.1->pytorch_tabular[extra]) (0.12.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\mdzak\anaconda3\envs\nnpartb\lib\site-packages (from matplotlib>3.1->pytorch_tabular[extra]) (4.43.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\mdzak\anaconda3\envs\nnpartb\lib\site-packages (from matplotlib>3.1->pytorch_tabular[extra]) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\mdzak\anaconda3\envs\nnpartb\lib\site-packages (from matplotlib>3.1->pytorch_tabular[extra]) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\mdzak\anaconda3\envs\nnpartb\lib\site-packages (from matplotlib>3.1->pytorch_tabular[extra]) (10.0.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\mdzak\anaconda3\envs\nnpartb\lib\site-packages (from matplotlib>3.1->pytorch_tabular[extra]) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\mdzak\anaconda3\envs\nnpartb\lib\site-packages (from matplotlib>3.1->pytorch_tabular[extra]) (2.8.2)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in c:\users\mdzak\anaconda3\envs\nnpartb\lib\site-packages (from omegaconf>=2.1.0->pytorch_tabular[extra]) (4.9.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\mdzak\anaconda3\envs\nnpartb\lib\site-packages (from pandas>=1.1.5->pytorch_tabular[extra]) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\mdzak\anaconda3\envs\nnpartb\lib\site-packages (from pandas>=1.1.5->pytorch_tabular[extra]) (2023.3)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\mdzak\anaconda3\envs\nnpartb\lib\site-packages (from plotly<5.15.0,>=5.13.0->pytorch_tabular[extra]) (8.2.3)
# Requirement already satisfied: fsspec[http]>2021.06.0 in c:\users\mdzak\anaconda3\envs\nnpartb\lib\site-packages (from pytorch-lightning<2.0.0,>=1.8.0->pytorch_tabular[extra]) (2023.9.2)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\mdzak\anaconda3\envs\nnpartb\lib\site-packages (from pytorch-lightning<2.0.0,>=1.8.0->pytorch_tabular[extra]) (4.8.0)
# Requirement already satisfied: lightning-utilities>=0.6.0.post0 in c:\users\mdzak\anaconda3\envs\nnpartb\lib\site-packages (from pytorch-lightning<2.0.0,>=1.8.0->pytorch_tabular[extra]) (0.9.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\mdzak\anaconda3\envs\nnpartb\lib\site-packages (from rich>=11.0.0->pytorch_tabular[extra]) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\mdzak\anaconda3\envs\nnpartb\lib\site-packages (from rich>=11.0.0->pytorch_tabular[extra]) (2.16.1)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\mdzak\anaconda3\envs\nnpartb\lib\site-packages (from scikit-learn>=1.0.0->pytorch_tabular[extra]) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\mdzak\anaconda3\envs\nnpartb\lib\site-packages (from scikit-learn>=1.0.0->pytorch_tabular[extra]) (3.2.0)
# Requirement already satisfied: absl-py>=0.4 in c:\users\mdzak\anaconda3\envs\nnpartb\lib\site-packages (from tensorboard!=2.5.0,>2.2.0->pytorch_tabular[extra]) (2.0.0)
# Requirement already satisfied: grpcio>=1.48.2 in c:\users\mdzak\anaconda3\envs\nnpartb\lib\site-packages (from tensorboard!=2.5.0,>2.2.0->pytorch_tabular[extra]) (1.59.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\mdzak\anaconda3\envs\nnpartb\lib\site-packages (from tensorboard!=2.5.0,>2.2.0->pytorch_tabular[extra]) (2.23.2)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in c:\users\mdzak\anaconda3\envs\nnpartb\lib\site-packages (from tensorboard!=2.5.0,>2.2.0->pytorch_tabular[extra]) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\mdzak\anaconda3\envs\nnpartb\lib\site-packages (from tensorboard!=2.5.0,>2.2.0->pytorch_tabular[extra]) (3.4.4)
# Requirement already satisfied: six>1.9 in c:\users\mdzak\anaconda3\envs\nnpartb\lib\site-packages (from tensorboard!=2.5.0,>2.2.0->pytorch_tabular[extra]) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\mdzak\anaconda3\envs\nnpartb\lib\site-packages (from tensorboard!=2.5.0,>2.2.0->pytorch_tabular[extra]) (0.7.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\mdzak\anaconda3\envs\nnpartb\lib\site-packages (from tensorboard!=2.5.0,>2.2.0->pytorch_tabular[extra]) (3.0.0)
# Requirement already satisfied: comm>=0.1.3 in c:\users\mdzak\anaconda3\envs\nnpartb\lib\site-packages (from ipywidgets->pytorch_tabular[extra]) (0.1.4)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\mdzak\anaconda3\envs\nnpartb\lib\site-packages (from ipywidgets->pytorch_tabular[extra]) (8.16.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\mdzak\anaconda3\envs\nnpartb\lib\site-packages (from ipywidgets->pytorch_tabular[extra]) (5.10.1)
# Requirement already satisfied: widgetsnbextension~=4.0.9 in c:\users\mdzak\anaconda3\envs\nnpartb\lib\site-packages (from ipywidgets->pytorch_tabular[extra]) (4.0.9)
# Requirement already satisfied: jupyterlab-widgets~=3.0.9 in c:\users\mdzak\anaconda3\envs\nnpartb\lib\site-packages (from ipywidgets->pytorch_tabular[extra]) (3.0.9)
# Requirement already satisfied: colorama in c:\users\mdzak\anaconda3\envs\nnpartb\lib\site-packages (from Click!=8.0.0,>=7.0->wandb==0.13.*->pytorch_tabular[extra]) (0.4.6)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in c:\users\mdzak\anaconda3\envs\nnpartb\lib\site-packages (from fsspec[http]>2021.06.0->pytorch-lightning<2.0.0,>=1.8.0->pytorch_tabular[extra]) (3.8.5)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\mdzak\anaconda3\envs\nnpartb\lib\site-packages (from GitPython!=3.1.29,>=1.0.0->wandb==0.13.*->pytorch_tabular[extra]) (4.0.10)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\mdzak\anaconda3\envs\nnpartb\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard!=2.5.0,>2.2.0->pytorch_tabular[extra]) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\mdzak\anaconda3\envs\nnpartb\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard!=2.5.0,>2.2.0->pytorch_tabular[extra]) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\mdzak\anaconda3\envs\nnpartb\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard!=2.5.0,>2.2.0->pytorch_tabular[extra]) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\mdzak\anaconda3\envs\nnpartb\lib\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard!=2.5.0,>2.2.0->pytorch_tabular[extra]) (1.3.1)
# Requirement already satisfied: backcall in c:\users\mdzak\anaconda3\envs\nnpartb\lib\site-packages (from ipython>=6.1.0->ipywidgets->pytorch_tabular[extra]) (0.2.0)
# Requirement already satisfied: decorator in c:\users\mdzak\anaconda3\envs\nnpartb\lib\site-packages (from ipython>=6.1.0->ipywidgets->pytorch_tabular[extra]) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\mdzak\anaconda3\envs\nnpartb\lib\site-packages (from ipython>=6.1.0->ipywidgets->pytorch_tabular[extra]) (0.19.0)
# Requirement already satisfied: matplotlib-inline in c:\users\mdzak\anaconda3\envs\nnpartb\lib\site-packages (from ipython>=6.1.0->ipywidgets->pytorch_tabular[extra]) (0.1.6)
# Requirement already satisfied: pickleshare in c:\users\mdzak\anaconda3\envs\nnpartb\lib\site-packages (from ipython>=6.1.0->ipywidgets->pytorch_tabular[extra]) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\mdzak\anaconda3\envs\nnpartb\lib\site-packages (from ipython>=6.1.0->ipywidgets->pytorch_tabular[extra]) (3.0.39)
# Requirement already satisfied: stack-data in c:\users\mdzak\anaconda3\envs\nnpartb\lib\site-packages (from ipython>=6.1.0->ipywidgets->pytorch_tabular[extra]) (0.6.2)
# Requirement already satisfied: exceptiongroup in c:\users\mdzak\anaconda3\envs\nnpartb\lib\site-packages (from ipython>=6.1.0->ipywidgets->pytorch_tabular[extra]) (1.1.3)
# Requirement already satisfied: mdurl~=0.1 in c:\users\mdzak\anaconda3\envs\nnpartb\lib\site-packages (from markdown-it-py>=2.2.0->rich>=11.0.0->pytorch_tabular[extra]) (0.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\mdzak\anaconda3\envs\nnpartb\lib\site-packages (from requests<3,>=2.0.0->wandb==0.13.*->pytorch_tabular[extra]) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mdzak\anaconda3\envs\nnpartb\lib\site-packages (from requests<3,>=2.0.0->wandb==0.13.*->pytorch_tabular[extra]) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\mdzak\anaconda3\envs\nnpartb\lib\site-packages (from requests<3,>=2.0.0->wandb==0.13.*->pytorch_tabular[extra]) (2.0.5)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mdzak\anaconda3\envs\nnpartb\lib\site-packages (from requests<3,>=2.0.0->wandb==0.13.*->pytorch_tabular[extra]) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\mdzak\anaconda3\envs\nnpartb\lib\site-packages (from werkzeug>=1.0.1->tensorboard!=2.5.0,>2.2.0->pytorch_tabular[extra]) (2.1.3)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\mdzak\anaconda3\envs\nnpartb\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning<2.0.0,>=1.8.0->pytorch_tabular[extra]) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\mdzak\anaconda3\envs\nnpartb\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning<2.0.0,>=1.8.0->pytorch_tabular[extra]) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\users\mdzak\anaconda3\envs\nnpartb\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning<2.0.0,>=1.8.0->pytorch_tabular[extra]) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\mdzak\anaconda3\envs\nnpartb\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning<2.0.0,>=1.8.0->pytorch_tabular[extra]) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\mdzak\anaconda3\envs\nnpartb\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning<2.0.0,>=1.8.0->pytorch_tabular[extra]) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\mdzak\anaconda3\envs\nnpartb\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning<2.0.0,>=1.8.0->pytorch_tabular[extra]) (1.3.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\mdzak\anaconda3\envs\nnpartb\lib\site-packages (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb==0.13.*->pytorch_tabular[extra]) (5.0.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\mdzak\anaconda3\envs\nnpartb\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets->pytorch_tabular[extra]) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\mdzak\anaconda3\envs\nnpartb\lib\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=6.1.0->ipywidgets->pytorch_tabular[extra]) (0.2.7)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in c:\users\mdzak\anaconda3\envs\nnpartb\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard!=2.5.0,>2.2.0->pytorch_tabular[extra]) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\mdzak\anaconda3\envs\nnpartb\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard!=2.5.0,>2.2.0->pytorch_tabular[extra]) (3.2.2)
# Requirement already satisfied: executing>=1.2.0 in c:\users\mdzak\anaconda3\envs\nnpartb\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets->pytorch_tabular[extra]) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\mdzak\anaconda3\envs\nnpartb\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets->pytorch_tabular[extra]) (2.4.0)
# Requirement already satisfied: pure-eval in c:\users\mdzak\anaconda3\envs\nnpartb\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets->pytorch_tabular[extra]) (0.2.2)
# Installing collected packages: torch
#   Attempting uninstall: torch
#     Found existing installation: torch 2.0.1
#     Uninstalling torch-2.0.1:
#       Successfully uninstalled torch-2.0.1
# Successfully installed torch-1.13.1

# %%
SEED = 42

import os

import random
random.seed(SEED)

import numpy as np
np.random.seed(SEED)

import pandas as pd

from pytorch_tabular import TabularModel
from pytorch_tabular.models import CategoryEmbeddingModelConfig
from pytorch_tabular.config import (
    DataConfig,
    OptimizerConfig,
    TrainerConfig,
)

# %% [markdown]
# > Divide the dataset (‘hdb_price_prediction.csv’) into train, validation and test sets by using entries from year 2019 and before as training data, year 2020 as validation data and year 2021 as test data.
# **Do not** use data from year 2022 and year 2023.

# %%
df = pd.read_csv('hdb_price_prediction.csv')

train_df = df[df['year'] <= 2019]
val_df = df[df['year'] == 2020]
test_df = df[df['year'] == 2021]

train_df
# Out:
#        month  year        town              full_address   nearest_stn  \
# 0          1  2017  ANG MO KIO  406 ANG MO KIO AVENUE 10    Ang Mo Kio
# 1          1  2017  ANG MO KIO   108 ANG MO KIO AVENUE 4    Ang Mo Kio
# 2          1  2017  ANG MO KIO   602 ANG MO KIO AVENUE 5  Yio Chu Kang
# 3          1  2017  ANG MO KIO  465 ANG MO KIO AVENUE 10    Ang Mo Kio
# 4          1  2017  ANG MO KIO   601 ANG MO KIO AVENUE 5  Yio Chu Kang
# ...      ...   ...         ...                       ...           ...
# 64052     12  2019      YISHUN      326 YISHUN RING ROAD        Yishun
# 64053     12  2019      YISHUN      326 YISHUN RING ROAD        Yishun
# 64054     12  2019      YISHUN      608 YISHUN STREET 61        Khatib
# 64055     12  2019      YISHUN      604 YISHUN STREET 61        Khatib
# 64056     12  2019      YISHUN      877 YISHUN STREET 81        Khatib
#
#        dist_to_nearest_stn  dist_to_dhoby  degree_centrality  \
# 0                 1.007264       7.006044           0.016807
# 1                 1.271389       7.983837           0.016807
# 2                 1.069743       9.090700           0.016807
# 3                 0.946890       7.519889           0.016807
# 4                 1.092551       9.130489           0.016807
# ...                    ...            ...                ...
# 64052             0.823163      14.421823           0.016807
# 64053             0.823163      14.421823           0.016807
# 64054             0.445869      13.498243           0.016807
# 64055             0.552769      13.598257           0.016807
# 64056             0.475885      12.738721           0.016807
#
#        eigenvector_centrality         flat_model_type  remaining_lease_years  \
# 0                    0.006243        2 ROOM, Improved              61.333333
# 1                    0.006243  3 ROOM, New Generation              60.583333
# 2                    0.002459  3 ROOM, New Generation              62.416667
# 3                    0.006243  3 ROOM, New Generation              62.083333
# 4                    0.002459  3 ROOM, New Generation              62.416667
# ...                       ...                     ...                    ...
# 64052                0.000382    EXECUTIVE, Apartment              67.583333
# 64053                0.000382   EXECUTIVE, Maisonette              67.583333
# 64054                0.000968    EXECUTIVE, Apartment              71.500000
# 64055                0.000968    EXECUTIVE, Apartment              71.500000
# 64056                0.000968   EXECUTIVE, Maisonette              67.083333
#
#        floor_area_sqm storey_range  resale_price
# 0                44.0     10 TO 12      232000.0
# 1                67.0     01 TO 03      250000.0
# 2                67.0     01 TO 03      262000.0
# 3                68.0     04 TO 06      265000.0
# 4                67.0     01 TO 03      265000.0
# ...               ...          ...           ...
# 64052           142.0     04 TO 06      580000.0
# 64053           146.0     07 TO 09      565000.0
# 64054           164.0     01 TO 03      633000.0
# 64055           164.0     10 TO 12      788888.0
# 64056           145.0     07 TO 09      618000.0
#
# [64057 rows x 14 columns]

# %% [markdown]
# > Refer to the documentation of **PyTorch Tabular** and perform the following tasks: https://pytorch-tabular.readthedocs.io/en/latest/#usage
# - Use **[DataConfig](https://pytorch-tabular.readthedocs.io/en/latest/data/)** to define the target variable, as well as the names of the continuous and categorical variables.
# - Use **[TrainerConfig](https://pytorch-tabular.readthedocs.io/en/latest/training/)** to automatically tune the learning rate. Set batch_size to be 1024 and set max_epoch as 50.
# - Use **[CategoryEmbeddingModelConfig](https://pytorch-tabular.readthedocs.io/en/latest/models/#category-embedding-model)** to create a feedforward neural network with 1 hidden layer containing 50 neurons.
# - Use **[OptimizerConfig](https://pytorch-tabular.readthedocs.io/en/latest/optimizer/)** to choose Adam optimiser. There is no need to set the learning rate (since it will be tuned automatically) nor scheduler.
# - Use **[TabularModel](https://pytorch-tabular.readthedocs.io/en/latest/tabular_model/)** to initialise the model and put all the configs together.

# %%
# TODO: Enter your code here
num_col_names = ["dist_to_nearest_stn", "dist_to_dhoby", "degree_centrality", "eigenvector_centrality", "remaining_lease_years", "floor_area_sqm"]
cat_col_names = ["month", "town", "flat_model_type", "storey_range"]

data_config = DataConfig(
    target=[
        "resale_price"
    ],  # target should always be a list. Multi-targets are only supported for regression. Multi-Task Classification is not implemented
    continuous_cols=num_col_names,
    categorical_cols=cat_col_names,
)

trainer_config = TrainerConfig(
    auto_lr_find=True,  # Runs the LRFinder to automatically derive a learning rate
    batch_size=1024,
    max_epochs=50,
)

model_config = CategoryEmbeddingModelConfig(
    task="regression",
    layers="50",  # Number of nodes in each layer
    activation="ReLU"  # Activation between each layers
)

optimizer_config = OptimizerConfig(optimizer='Adam')

tabular_model = TabularModel(
    data_config=data_config,
    model_config=model_config,
    optimizer_config=optimizer_config,
    trainer_config=trainer_config,
)

tabular_model.fit(train=train_df, validation=val_df)
result = tabular_model.evaluate(test_df)
pred_df = tabular_model.predict(test_df)
rmse = np.sqrt(result[0]['test_mean_squared_error'])
def r_squared_numpy(y_true, y_pred):
    y_mean = np.mean(y_true)
    ss_tot = np.sum((y_true - y_mean)**2)
    ss_res = np.sum((y_true - y_pred)**2)
    r2 = 1 - (ss_res / ss_tot)
    return r2
ground_truth = pred_df['resale_price'].to_numpy()
pred = pred_df['resale_price_prediction'].to_numpy()

r2 = r_squared_numpy(ground_truth, pred)
print("RMSE: ", rmse)
print("R2: ", r2)
# Out:
# 2023-10-03 16:21:31,443 - {pytorch_tabular.tabular_model:105} - INFO - Experiment Tracking is turned off
# Global seed set to 42
# 2023-10-03 16:21:31,468 - {pytorch_tabular.tabular_model:473} - INFO - Preparing the DataLoaders
# 2023-10-03 16:21:31,470 - {pytorch_tabular.tabular_datamodule:290} - INFO - Setting up the datamodule for regression task
# 2023-10-03 16:21:31,560 - {pytorch_tabular.tabular_model:521} - INFO - Preparing the Model: CategoryEmbeddingModel
# 2023-10-03 16:21:31,585 - {pytorch_tabular.tabular_model:268} - INFO - Preparing the Trainer
# c:\Users\mdzak\anaconda3\envs\nnpartb\lib\site-packages\pytorch_lightning\trainer\connectors\accelerator_connector.py:589: LightningDeprecationWarning: The Trainer argument `auto_select_gpus` has been deprecated in v1.9.0 and will be removed in v2.0.0. Please use the function `pytorch_lightning.accelerators.find_usable_cuda_devices` instead.
#   rank_zero_deprecation(
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# 2023-10-03 16:21:31,629 - {pytorch_tabular.tabular_model:573} - INFO - Auto LR Find Started
# c:\Users\mdzak\anaconda3\envs\nnpartb\lib\site-packages\pytorch_lightning\callbacks\model_checkpoint.py:613: UserWarning: Checkpoint directory C:\Users\mdzak\Desktop\GitHub\CZ4042_NN\submission\saved_models exists and is not empty.
#   rank_zero_warn(f"Checkpoint directory {dirpath} exists and is not empty.")
# c:\Users\mdzak\anaconda3\envs\nnpartb\lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:224: PossibleUserWarning: The dataloader, train_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 16 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# c:\Users\mdzak\anaconda3\envs\nnpartb\lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:224: PossibleUserWarning: The dataloader, val_dataloader 0, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 16 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# c:\Users\mdzak\anaconda3\envs\nnpartb\lib\site-packages\pytorch_lightning\core\module.py:493: UserWarning: You called `self.log('valid_loss', ..., logger=True)` but have no logger configured. You can enable one by doing `Trainer(logger=ALogger(...))`
#   rank_zero_warn(
# c:\Users\mdzak\anaconda3\envs\nnpartb\lib\site-packages\pytorch_lightning\core\module.py:493: UserWarning: You called `self.log('valid_mean_squared_error', ..., logger=True)` but have no logger configured. You can enable one by doing `Trainer(logger=ALogger(...))`
#   rank_zero_warn(
# Finding best initial lr:   0%|          | 0/100 [00:00<?, ?it/s]
# c:\Users\mdzak\anaconda3\envs\nnpartb\lib\site-packages\pytorch_lightning\core\module.py:493: UserWarning: You called `self.log('train_loss', ..., logger=True)` but have no logger configured. You can enable one by doing `Trainer(logger=ALogger(...))`
#   rank_zero_warn(
# c:\Users\mdzak\anaconda3\envs\nnpartb\lib\site-packages\pytorch_lightning\core\module.py:493: UserWarning: You called `self.log('train_mean_squared_error', ..., logger=True)` but have no logger configured. You can enable one by doing `Trainer(logger=ALogger(...))`
#   rank_zero_warn(
# `Trainer.fit` stopped: `max_steps=100` reached.
# Learning rate set to 0.5754399373371567
# Restoring states from the checkpoint path at c:\Users\mdzak\Desktop\GitHub\CZ4042_NN\submission\.lr_find_c31433a4-199d-43fc-b76a-ef16bd24c3eb.ckpt
# Restored all states from the checkpoint file at c:\Users\mdzak\Desktop\GitHub\CZ4042_NN\submission\.lr_find_c31433a4-199d-43fc-b76a-ef16bd24c3eb.ckpt
# 2023-10-03 16:21:34,667 - {pytorch_tabular.tabular_model:575} - INFO - Suggested LR: 0.5754399373371567. For plot and detailed analysis, use `find_learning_rate` method.
# 2023-10-03 16:21:34,668 - {pytorch_tabular.tabular_model:582} - INFO - Training Started
# ┏━━━┳━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓
# ┃   ┃ Name             ┃ Type                      ┃ Params ┃
# ┡━━━╇━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩
# │ 0 │ _backbone        │ CategoryEmbeddingBackbone │  2.9 K │
# │ 1 │ _embedding_layer │ Embedding1dLayer          │  1.5 K │
# │ 2 │ head             │ LinearHead                │     51 │
# │ 3 │ loss             │ MSELoss                   │      0 │
# └───┴──────────────────┴───────────────────────────┴────────┘
# Trainable params: 4.5 K
# Non-trainable params: 0
# Total params: 4.5 K
# Total estimated model params size (MB): 0
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 2023-10-03 16:21:54,037 - {pytorch_tabular.tabular_model:584} - INFO - Training the model completed
# 2023-10-03 16:21:54,039 - {pytorch_tabular.tabular_model:1258} - INFO - Loading the best model
# Output()
# c:\Users\mdzak\anaconda3\envs\nnpartb\lib\site-packages\pytorch_lightning\core\module.py:493: UserWarning: You
# called `self.log('test_loss', ..., logger=True)` but have no logger configured. You can enable one by doing
# `Trainer(logger=ALogger(...))`
#   rank_zero_warn(
# c:\Users\mdzak\anaconda3\envs\nnpartb\lib\site-packages\pytorch_lightning\core\module.py:493: UserWarning: You
# called `self.log('test_mean_squared_error', ..., logger=True)` but have no logger configured. You can enable one by
# doing `Trainer(logger=ALogger(...))`
#   rank_zero_warn(
# c:\Users\mdzak\anaconda3\envs\nnpartb\lib\site-packages\pytorch_lightning\utilities\cloud_io.py:33: LightningDeprecationWarning: `pytorch_lightning.utilities.cloud_io.get_filesystem` has been deprecated in v1.8.0 and will be removed in v2.0.0. Please use `lightning_fabric.utilities.cloud_io.get_filesystem` instead.
#   rank_zero_deprecation(
# c:\Users\mdzak\anaconda3\envs\nnpartb\lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:224: PossibleUserWarning: The dataloader, test_dataloader 0, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 16 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │         test_loss         │       5882418688.0        │
# │  test_mean_squared_error  │       5882418688.0        │
# └───────────────────────────┴───────────────────────────┘
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# RMSE:  76696.92750038947
# R2:  0.7776187406639129

# %% [markdown]
# > Report the test RMSE error and the test R2 value that you obtained.

# %% [markdown]
# <!-- \# TODO: \<Enter your answer here\> -->
#
# RMSE: 76696.92750038947
# R2: 0.7776187406639129

# %% [markdown]
# > Print out the corresponding rows in the dataframe for the top 25 test samples with the largest errors. Identify a trend in these poor predictions and suggest a way to reduce these errors.

# %%
pred_df_25 = pred_df
pred_df_25['abs_sq_error'] = (pred_df_25['resale_price'] - pred_df_25['resale_price_prediction'])**2
sorted_pred_df_25 = pred_df_25.sort_values(by='abs_sq_error', ascending=False)

sorted_pred_df_25.head(25)
# Out:
#         month  year          town                full_address    nearest_stn  \
# 92405      11  2021   BUKIT MERAH            46 SENG POH ROAD    Tiong Bahru
# 90957       6  2021   BUKIT BATOK  288A BUKIT BATOK STREET 25    Bukit Batok
# 112128     12  2021      TAMPINES      156 TAMPINES STREET 12       Tampines
# 90608      12  2021        BISHAN       273B BISHAN STREET 24         Bishan
# 106192     12  2021    QUEENSTOWN              89 DAWSON ROAD     Queenstown
# 91871       6  2021   BUKIT MERAH         17 TIONG BAHRU ROAD    Tiong Bahru
# 93825       8  2021  CENTRAL AREA       4 TANJONG PAGAR PLAZA  Tanjong Pagar
# 92504      12  2021   BUKIT MERAH            49 KIM PONG ROAD    Tiong Bahru
# 105695      6  2021    QUEENSTOWN              91 DAWSON ROAD     Queenstown
# 90432       8  2021        BISHAN       275A BISHAN STREET 24         Bishan
# 92299      10  2021   BUKIT MERAH         36 MOH GUAN TERRACE    Tiong Bahru
# 92442      11  2021   BUKIT MERAH          127D KIM TIAN ROAD    Tiong Bahru
# 93895      11  2021  CENTRAL AREA       3 TANJONG PAGAR PLAZA  Tanjong Pagar
# 105699      6  2021    QUEENSTOWN              91 DAWSON ROAD     Queenstown
# 88081       8  2021    ANG MO KIO    310A ANG MO KIO AVENUE 1     Ang Mo Kio
# 106057     10  2021    QUEENSTOWN              92 DAWSON ROAD     Queenstown
# 90521      10  2021        BISHAN        237 BISHAN STREET 22         Bishan
# 92340      10  2021   BUKIT MERAH            56 HAVELOCK ROAD    Tiong Bahru
# 91694       4  2021   BUKIT MERAH          35 LIM LIAK STREET    Tiong Bahru
# 98379      12  2021       HOUGANG        615 HOUGANG AVENUE 8        Hougang
# 92226       9  2021   BUKIT MERAH          96A HENDERSON ROAD    Tiong Bahru
# 105468      3  2021    QUEENSTOWN              90 DAWSON ROAD     Queenstown
# 92533      12  2021   BUKIT MERAH          2C BOON TIONG ROAD    Tiong Bahru
# 105966      9  2021    QUEENSTOWN              91 DAWSON ROAD     Queenstown
# 92066       8  2021   BUKIT MERAH         48 MOH GUAN TERRACE    Tiong Bahru
#
#         dist_to_nearest_stn  dist_to_dhoby  degree_centrality  \
# 92405              0.581977       2.309477           0.016807
# 90957              1.292540      10.763777           0.016807
# 112128             0.370873      12.479752           0.033613
# 90608              0.776182       6.297489           0.033613
# 106192             0.658035       3.807573           0.016807
# 91871              0.693391       2.058774           0.016807
# 93825              0.451637       2.594828           0.016807
# 92504              0.468378       2.365532           0.016807
# 105695             0.745596       3.720593           0.016807
# 90432              0.827889       6.370404           0.033613
# 92299              0.490926       2.278805           0.016807
# 92442              0.686789       2.664024           0.016807
# 93895              0.490378       2.630876           0.016807
# 105699             0.745596       3.720593           0.016807
# 88081              0.860056       7.263401           0.016807
# 106057             0.584731       3.882019           0.016807
# 90521              0.947205       6.663943           0.033613
# 92340              0.451387       2.128424           0.016807
# 91694              0.481551       2.262574           0.016807
# 98379              0.899849       8.828235           0.016807
# 92226              0.586629       2.932814           0.016807
# 105468             0.701852       3.763948           0.016807
# 92533              0.656363       1.982722           0.016807
# 105966             0.745596       3.720593           0.016807
# 92066              0.538563       2.345844           0.016807
#
#         eigenvector_centrality                 flat_model_type  \
# 92405                 0.047782                3 ROOM, Standard
# 90957                 0.000217            EXECUTIVE, Apartment
# 112128                0.000229           EXECUTIVE, Maisonette
# 90608                 0.015854                    5 ROOM, DBSS
# 106192                0.008342  4 ROOM, Premium Apartment Loft
# 91871                 0.047782                3 ROOM, Standard
# 93825                 0.103876           5 ROOM, Adjoined flat
# 92504                 0.047782                3 ROOM, Standard
# 105695                0.008342  4 ROOM, Premium Apartment Loft
# 90432                 0.015854                    5 ROOM, DBSS
# 92299                 0.047782                3 ROOM, Standard
# 92442                 0.047782                5 ROOM, Improved
# 93895                 0.103876           5 ROOM, Adjoined flat
# 105699                0.008342  4 ROOM, Premium Apartment Loft
# 88081                 0.006243                5 ROOM, Improved
# 106057                0.008342  4 ROOM, Premium Apartment Loft
# 90521                 0.015854                5 ROOM, Improved
# 92340                 0.047782                5 ROOM, Improved
# 91694                 0.047782                3 ROOM, Standard
# 98379                 0.001507            EXECUTIVE, Apartment
# 92226                 0.047782                5 ROOM, Improved
# 105468                0.008342  4 ROOM, Premium Apartment Loft
# 92533                 0.047782                5 ROOM, Improved
# 105966                0.008342  4 ROOM, Premium Apartment Loft
# 92066                 0.047782                3 ROOM, Standard
#
#         remaining_lease_years  floor_area_sqm storey_range  resale_price  \
# 92405               50.166667            88.0     01 TO 03      780000.0
# 90957               75.583333           144.0     10 TO 12      968000.0
# 112128              61.750000           148.0     01 TO 03      998000.0
# 90608               88.833333           120.0     37 TO 39     1360000.0
# 106192              93.333333           109.0     04 TO 06      968000.0
# 91871               50.583333            88.0     01 TO 03      680888.0
# 93825               54.583333           118.0     16 TO 18      938000.0
# 92504               50.166667            88.0     01 TO 03      695000.0
# 105695              93.916667            97.0     07 TO 09      930000.0
# 90432               88.916667           120.0     25 TO 27     1280000.0
# 92299               50.333333            88.0     01 TO 03      690000.0
# 92442               90.333333           113.0     16 TO 18     1165000.0
# 93895               54.250000           139.0     07 TO 09      958000.0
# 105699              93.916667           109.0     31 TO 33     1032888.0
# 88081               90.166667           121.0     28 TO 30     1100000.0
# 106057              93.500000            97.0     13 TO 15      958000.0
# 90521               69.583333           121.0     07 TO 09      988000.0
# 92340               90.750000           114.0     34 TO 36     1245000.0
# 91694               50.833333            88.0     01 TO 03      680000.0
# 98379               63.666667           142.0     04 TO 06      873000.0
# 92226               96.750000           113.0     28 TO 30     1220000.0
# 105468              94.166667            95.0     10 TO 12      920000.0
# 92533               78.083333           115.0     28 TO 30     1130000.0
# 105966              93.666667            97.0     25 TO 27      968800.0
# 92066               50.500000            77.0     01 TO 03      628000.0
#
#         resale_price_prediction  abs_sq_error
# 92405              3.646865e+05  1.724853e+11
# 90957              6.144982e+05  1.249635e+11
# 112128             6.555936e+05  1.172422e+11
# 90608              1.020588e+06  1.152002e+11
# 106192             6.359388e+05  1.102647e+11
# 91871              3.583568e+05  1.040264e+11
# 93825              6.179541e+05  1.024294e+11
# 92504              3.760022e+05  1.017596e+11
# 105695             6.124678e+05  1.008267e+11
# 90432              9.629781e+05  1.005029e+11
# 92299              3.759402e+05  9.863357e+10
# 92442              8.518172e+05  9.808343e+10
# 93895              6.479514e+05  9.613015e+10
# 105699             7.242336e+05  9.526752e+10
# 88081              7.917690e+05  9.500635e+10
# 106057             6.501535e+05  9.476947e+10
# 90521              6.803419e+05  9.465352e+10
# 92340              9.410490e+05  9.238621e+10
# 91694              3.766706e+05  9.200875e+10
# 98379              5.709140e+05  9.125595e+10
# 92226              9.209055e+05  8.945752e+10
# 105468             6.215141e+05  8.909382e+10
# 92533              8.315202e+05  8.909016e+10
# 105966             6.728788e+05  8.756935e+10
# 92066              3.324644e+05  8.734127e+10

# %% [markdown]
# \# TODO: \<Enter your answer here\>
